# %% [markdown]
# <a href="https://colab.research.google.com/github/Thokalacharan/Machine-learning/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
file = pd.read_csv('/content/simplelinearregression.csv')

# %%
print(file)
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000

# %%
file
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(file.Age,file.Premium)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(file[["Age"]], file["Premium"])
# Out:
# LinearRegression()

# %%
model.predict([[22]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15690.06849315])

# %%
data = pd.read_csv('/content/insurance_data.csv')

# %%
data
# Out:
#     Age   Income   BMI  Smoker  Premium
# 0    18   200000  19.5       0    10000
# 1    22   250000  21.0       0    15000
# 2    23   300000  22.5       0    18000
# 3    26   350000  23.0       0    21000
# 4    28   400000  24.5       0    24000
# 5    31   450000  25.0       0    26500
# 6    33   500000  26.0       0    27000
# 7    35   550000  27.5       1    35000
# 8    38   600000  28.0       1    38000
# 9    40   650000  29.0       1    42000
# 10   42   700000  30.0       1    46000
# 11   45   800000  31.5       1    52000
# 12   50   900000  33.0       1    60000
# 13   55  1000000  34.5       1    68000
# 14   60  1200000  36.0       1    75000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.Age,data.Smoker)

# %% [markdown]
# # Task
# Push the current Colab notebook to a GitHub repository.

# %% [markdown]
# ## Save Notebook
#
# ### Subtask:
# Save the current Colab notebook content to a file, typically a .ipynb file.

# %% [markdown]
# ### Subtask:
# Save the current Colab notebook content to a file, typically a .ipynb file.
#
# #### Instructions
# 1. Go to the 'File' menu in Google Colab.
# 2. Select 'Save a copy in GitHub' to directly save the notebook to a GitHub repository, or 'Save a copy in Drive' if you wish to save it locally first and then upload it to GitHub manually.
# 3. Alternatively, you can select 'Download' and then 'Download .ipynb' to save the notebook to your local machine.

# %% [markdown]
# ## Clone GitHub Repository
#
# ### Subtask:
# Clone the specified GitHub repository to access it locally.

# %% [markdown]
# **Reasoning**:
# To clone a GitHub repository, the `!git clone` command is used in a code cell. I will provide a placeholder URL and instruct the user to replace it with their actual repository URL.

# %%
print("Please replace the placeholder URL below with your actual GitHub repository URL.")
# !git clone https://github.com/your_username/your_repository.git
# !git clone https://github.com/amankharwal/Website-data.git
# Out:
# Please replace the placeholder URL below with your actual GitHub repository URL.
# Cloning into 'Website-data'...
# remote: Enumerating objects: 412, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 412 (delta 131), reused 107 (delta 107), pack-reused 273 (from 1)
# Receiving objects: 100% (412/412), 203.08 MiB | 26.88 MiB/s, done.
# Resolving deltas: 100% (137/137), done.
# Updating files: 100% (135/135), done.

# %% [markdown]
# ### Subtask:
# Save and Push Notebook to GitHub
#
# #### Instructions
# 1. **Navigate to the cloned repository:** Open a new code cell and use the `cd` command to change the current directory to the cloned repository. For example, if your repository is named `my_repository`, you would use `!cd my_repository`.
# 2. **Save the current notebook:** Go to `File` > `Save a copy in GitHub` in the Colab menu. Select the cloned repository as the destination.
#    *Alternatively, if you downloaded the notebook locally:* Upload the `.ipynb` file to the cloned directory within Colab using the file browser on the left pane.
# 3. **Add the notebook to staging:** In a new code cell, use `!git add <notebook_name.ipynb>` to stage your notebook for commit. Replace `<notebook_name.ipynb>` with the actual name of your notebook.
# 4. **Commit the changes:** In the same code cell, use `!git commit -m "Add Colab notebook"` to commit the staged changes. You can customize the commit message.
# 5. **Push to GitHub:** Finally, use `!git push origin main` (or `!git push origin master` depending on your repository's default branch) to push your changes to the remote GitHub repository. You might be prompted to enter your GitHub username and Personal Access Token (PAT).

# %% [markdown]
# ## Save and Push Notebook to GitHub
#
# ### Subtask:
# Execute the steps to save the current notebook into the cloned repository, stage it, commit it, and push it to GitHub.

# %% [markdown]
# **Reasoning**:
# The first step is to change the current working directory to the cloned repository using the `cd` command, as specified in the instructions.

# %%
import os
os.chdir('Website-data')
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /content/Website-data

# %% [markdown]
# #### Step 2: Save the current notebook to the cloned repository
#
# To save this notebook into the `Website-data` repository, please follow these steps:
#
# 1.  Go to the **'File'** menu at the top of your Google Colab interface.
# 2.  Select **'Save a copy in GitHub'**.
# 3.  A dialog box will appear. You should select the `Website-data` repository as the destination for saving this notebook.
# 4.  Once saved, the notebook will appear in your GitHub repository.
#
# *Alternatively, if you downloaded the notebook locally in a previous step, you would upload the `.ipynb` file from your local machine into the `Website-data` directory within the Colab file browser (the folder icon on the left sidebar).*
#
# After successfully saving the notebook to your GitHub repository, proceed to the next step.

# %% [markdown]
# **Reasoning**:
# Now that the user has been instructed to save the notebook, the next step in the process is to stage the notebook file for commit using `git add`. I will provide a placeholder for the notebook name and instruct the user to replace it.

# %%
print("Please replace '<notebook_name.ipynb>' with the actual name of your notebook file.")
# !git add <notebook_name.ipynb>
# Out:
# Please replace '<notebook_name.ipynb>' with the actual name of your notebook file.
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `git add <notebook_name.ipynb>'

# %% [markdown]
# **Reasoning**:
# The previous `git add` command failed because the placeholder for the notebook name was not replaced. To successfully stage the notebook, the actual file name is required. The next step is to list the files in the current directory to help the user identify the correct notebook file name.

# %%
print("Please run this cell to see the files in your current directory. Identify the exact name of your Colab notebook file from the output, then use it in the next `git add` command.")
# !ls -F
# Out:
# Please run this cell to see the files in your current directory. Identify the exact name of your Colab notebook file from the output, then use it in the next `git add` command.
#  23_09_2022.csv
#  AAPL.csv
# 'adidas quarterly sales.csv'
#  advertising.csv
#  Advertising.csv
#  AER_credit_card_data.csv
#  airline-passengers.csv
#  amazon_alexa.tsv
#  arima.rar
#  articles.csv
#  association_rule_market_basket_analysis.ipynb
#  Automatic_EDA.ipynb
#  auto-mpg.csv
#  bank.csv
#  bbc-news-data.csv
#  Best_Streaming_Service_Analysis.ipynb
#  Billionaire.csv
#  Bitcoin_Price_Prediction.ipynb
#  book.txt
#  BRCA.csv
# 'car data.csv'
#  CarPrice.csv
#  challenge.txt
#  class_grades.csv
#  clock.gif
#  cohort_analysis.ipynb
#  colors.csv
#  colour.jpeg
#  Copy_of_RCB_vs_DC.ipynb
# 'Cost of living.csv'
# 'COVID19 data for overall INDIA.csv'
#  credit.csv
#  customers.csv
#  dailyActivity_merged.csv
#  data_banknote_authentication.txt
#  database.csv
#  datanew.json
#  Data.rar
#  dataset.csv
# ...
